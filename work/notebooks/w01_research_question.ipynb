# %% [markdown]
# <a href="https://colab.research.google.com/github/zaraabbasi454-svg/flyrankml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/zaraabbasi454-svg/flyrankml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ### My Lane: Content Refresh
#
# My lane is Content Refresh. I want to explore which observable page and search-performance signals are associated with pages that may need a refresh. I chose this area because the Week-1 data showed that simple assumptions do not always match what is observed in the data. My goal is to build decision-support that can help prioritize pages for review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### The Question
#
# The decision is which pages should be prioritized for content-refresh review. A content or SEO team would use the recommendation to decide which pages to investigate first. A wrong recommendation could waste time and resources on a page that does not need attention, while missing a page that may benefit from review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Declining rate:", round(df["is_declining_label"].mean(), 3))

corr = df["search_volume"].corr(df["impressions_90d"])
print("Search volume vs impressions correlation:", round(corr, 3))

# %% [markdown]
# ### Quick Look at the Data
#
# The dataset contains 30,000 pages. The observed declining rate is about 54.2%. The correlation between search volume and 90-day impressions is 0.001, which is near zero. This directional observation suggests that keyword search volume alone does not strongly correspond with the impressions received by a page in this dataset. These observations make it useful to investigate other signals for content-refresh prioritization.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
# !git clone https://github.com/zaraabbasi454-svg/flyrankml-internship.git
# %cd flyrankml-internship
# !pip install -r requirements.txt
# !python scripts/run_all.py
# Out:
# Cloning into 'flyrankml-internship'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (135/135), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 135 (delta 45), reused 93 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (135/135), 1.87 MiB | 12.11 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
# /content/flyrankml-internship
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 22.6 MB/s eta 0:00:00
# ...
#
# ...
# ▶ Step 1/5 — Prepare features — clean the data, build the feature vector, define the label
# ...
# Prepared 30,000 rows from 30,000 raw rows
# Wrote /content/flyrankml-internship/data/processed/refresh_feature_vector.csv
#
# ...
# ▶ Step 2/5 — Baseline — a transparent hand-written rule to beat
# ...
# Wrote baseline queue: /content/flyrankml-internship/data/processed/baseline_refresh_queue.csv
# Top-50 declining rate (full data, not the evaluated holdout Precision@50): 0.340
#
# ...

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
